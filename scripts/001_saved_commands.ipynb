# %% [markdown]
# ## Main command
# ```bash
# export FLOWLOT_CONFIG=scripts/repeated_benchmark_blast110.env
# bash scripts/hpc_repeated_benchmark.sh init
# bash scripts/hpc_repeated_benchmark.sh submit
# ```

# %% [markdown]
# ## Main Command
# ```bash
# export FLOWLOT_CONFIG=scripts/repeated_benchmark_flowcapii.env
# bash scripts/hpc_repeated_benchmark.sh init
# bash scripts/hpc_repeated_benchmark.sh submit
# ```

# %% [markdown]
# ## For periodical checking
# ```bash
# squeue -u qpb3vt
#
# ls data/results/repeated_classification_blast110/shards | wc -l
# # Also
# tail -n 20 data/results/repeated_classification_blast110/logs/*.out
#
# ```

# %% [markdown]
# for aggregation
# ```bash
# export FLOWLOT_CONFIG=scripts/repeated_benchmark_blast110.env
# bash scripts/hpc_repeated_benchmark.sh aggregate
# ```

# %% [markdown]
# squeue -u $USER
# ls data/results/repeated_classification_flowcapii/shards/*.json | wc -l
# tail -n 25 data/results/repeated_classification_flowcapii/logs/*.out
